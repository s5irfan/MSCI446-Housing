# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import preprocessing
from sklearn.cross_validation import KFold, cross_val_score

dataset = pd.read_csv('Numeric.csv')
'''
print(dataset)
'''

#encode categorical variable
'''
print("The transformed Type is:",transfomed_Q9)
'''
#predict Type given Q1 ( )
CV =  dataset.Type.reshape((len(dataset.Type), 1))

data = (dataset.ix[:,'Q1':'Q2'].values).reshape((len(dataset.Type), 2))
'''
data = dataset.Q9.reshape((len(dataset.Q9), 1))
print(data)
print(CV)
'''
# Create linear regression object
#
DT = DecisionTreeClassifier(criterion="entropy", min_samples_leaf = 2)

# Train the model using the training sets
DT.fit(data, CV)

# the model
with open("predict_Type.dot", 'w') as f:
    f = tree.export_graphviz(DT, out_file=f, feature_names=["Q1","Q2"], class_names=["Luxury apartment","Shared Apartments","House","Dorms","Single bedroom apartment"], filled=True)



#predict the class for each data point
predicted = DT.predict(data)
print("Predictions: \n", np.array([predicted]).T)

# predict the probability/likelihood of the prediction
print("Probability of prediction: \n",DT.predict_proba(data))

print("Feature importance: ", DT.feature_importances_)

print("Accuracy score for the model: \n", DT.score(data,CV))

print(metrics.confusion_matrix(CV, predicted, labels=["Luxury apartment","Shared Apartments","House","Dorms","Single bedroom apartment"]))

# Calculating 5 fold cross validation results
model = DecisionTreeClassifier()
kf = KFold(len(CV), n_folds=2)
scores = cross_val_score(model, data, CV, cv=kf)
print("MSE of every fold in 5 fold cross validation: ", abs(scores))
print("Mean of the 5 fold cross-validation: %0.2f" % abs(scores.mean()))

print("Which type is suggested, if resondant chooses to do Netflix and chill in his free time and prefers to stay at corner of cafe: ", DT.predict([1,0]),DT.predict_proba([1,0]))
# Out:
# Predictions:
#  [['Dorms']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['House']
#  ['Dorms']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['House']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['House']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Dorms']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Dorms']
#  ['House']
#  ['Dorms']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['Dorms']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['House']
#  ['Dorms']
#  ['Dorms']
#  ['House']
#  ['Shared Apartments']
#  ['House']
#  ['Shared Apartments']
#  ['Dorms']
#  ['Dorms']]
# Probability of prediction:
#  [[ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.          0.25        0.          0.75        0.        ]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.          0.25        0.          0.75        0.        ]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.          0.25        0.          0.75        0.        ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.          0.25        0.          0.75        0.        ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.625       0.125       0.125       0.          0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.14285714  0.28571429  0.07142857  0.35714286  0.14285714]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.06451613  0.29032258  0.06451613  0.4516129   0.12903226]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.18181818  0.45454545  0.09090909  0.27272727  0.        ]
#  [ 0.6         0.1         0.2         0.          0.1       ]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.22033898  0.30508475  0.15254237  0.28813559  0.03389831]
#  [ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]
#  [ 0.34375     0.1875      0.09375     0.25        0.125     ]
#  [ 0.625       0.125       0.125       0.          0.125     ]]
# Feature importance:  [ 0.49977035  0.50022965]
# Accuracy score for the model:
#  0.419689119171
# [[ 0  0  0  0  0]
#  [ 0 36 20  8  0]
#  [ 0 18 23  8  0]
#  [ 0  6 15 22  0]
#  [ 0  8  2  6  0]]
# MSE of every fold in 5 fold cross validation:  [ 0.31958763  0.36458333]
# Mean of the 5 fold cross-validation: 0.34
# Which type is suggested, if resondant chooses to do Netflix and chill in his free time and prefers to stay at corner of cafe:  ['Shared Apartments'] [[ 0.08333333  0.16666667  0.08333333  0.58333333  0.08333333]]
# C:\Users\sana_\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\sana_\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# C:\Users\sana_\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Users\sana_\Anaconda3\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
